# %%
# LE ARQUIVOS E SALVA A
df = spark.read.format("json").load('s3://solar-weather/bronze/').select("*","_metadata.file_name")
df.write \
    .format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable("bronze.solar_production")
